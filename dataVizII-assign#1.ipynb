# %%
import numpy as np
import pandas as pd

print("m")


df = pd.read_csv("Crime_Data_from_2010_to_Present.csv")
# Out:
# m

# %%
df.head(3)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0        809    01/17/2015    01/16/2015           2130        9     Van Nuys
# 1  141801696    01/01/2015    01/01/2015            230       18    Southeast
# 2  141816266    11/05/2015    10/01/2015            800       12  77th Street
#
#    Reporting District  Crime Code             Crime Code Description  \
# 0                 938         510                   VEHICLE - STOLEN
# 1                1823         626  INTIMATE PARTNER - SIMPLE ASSAULT
# 2                1249         805                            PIMPING
#
#                    MO Codes          ...           \
# 0                       NaN          ...
# 1  2000 0444 0429 0416 1276          ...
# 2            1402 0908 0913          ...
#
#                                Weapon Description Status Code  \
# 0                                             NaN          IC
# 1  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          IC
# ...

# %%
df['Time Occurred'] = df['Time Occurred'].astype(int).apply(lambda x: x/100).astype(str)

# %%
df.head(3)
# Out:
#    DR Number Date Reported Date Occurred Time Occurred  Area ID    Area Name  \
# 0        809    01/17/2015    01/16/2015          21.3        9     Van Nuys
# 1  141801696    01/01/2015    01/01/2015           2.3       18    Southeast
# 2  141816266    11/05/2015    10/01/2015           8.0       12  77th Street
#
#    Reporting District  Crime Code             Crime Code Description  \
# 0                 938         510                   VEHICLE - STOLEN
# 1                1823         626  INTIMATE PARTNER - SIMPLE ASSAULT
# 2                1249         805                            PIMPING
#
#                    MO Codes          ...           \
# 0                       NaN          ...
# 1  2000 0444 0429 0416 1276          ...
# 2            1402 0908 0913          ...
#
#                                Weapon Description Status Code  \
# 0                                             NaN          IC
# 1  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          IC
# ...

# %%
#df.to_csv('crimeLA', sep='\t')
df['Time Occurred'] = pd.to_datetime(df['Date Occurred'] + ' ' + df['Time Occurred'], format = "%m/%d/%Y %H.%M")

# %%
df.head(3)
# Out:
#    DR Number Date Reported Date Occurred       Time Occurred  Area ID  \
# 0        809    01/17/2015    01/16/2015 2015-01-16 21:03:00        9
# 1  141801696    01/01/2015    01/01/2015 2015-01-01 02:03:00       18
# 2  141816266    11/05/2015    10/01/2015 2015-10-01 08:00:00       12
#
#      Area Name  Reporting District  Crime Code  \
# 0     Van Nuys                 938         510
# 1    Southeast                1823         626
# 2  77th Street                1249         805
#
#               Crime Code Description                  MO Codes  \
# 0                   VEHICLE - STOLEN                       NaN
# 1  INTIMATE PARTNER - SIMPLE ASSAULT  2000 0444 0429 0416 1276
# 2                            PIMPING            1402 0908 0913
#
#            ...                                       Weapon Description  \
# 0          ...                                                      NaN
# 1          ...           STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# ...

# %%
df.to_csv('crimeLA.csv', sep='\t')
